# %% [markdown]
# ## Chebyshev Polynomial Filter Design

# %%
# # Uncomment the following lines to run the notebook in the root directory of the repository
# import os

# # set the current working directory
# curr_path = os.getcwd().split("/")[:-2]
# curr_path = "/".join(curr_path)
# os.chdir(curr_path)

# %%
import numpy as np
from pytspl import load_dataset, SCPlot

sc, coordinates, _ = load_dataset("paper")
# create a plot
scplot = SCPlot(sc, coordinates)
# Out:
# Num. of nodes: 7
# Num. of edges: 10
# Num. of triangles: 3
# Shape: (7, 10, 3)
# Max Dimension: 2
# Coordinates: 7
# Flow: 10

# %%
# define the edge flow and noisy edge flow
f0 = np.array([-0.0689, -0.1378, 0.2067, -0.0689, 0.3445, -0.5512, 0.5512, 0.3675, 0.1837, -0.1837])
f = np.array([0.0323, 0.4980, 2.3825, 0.8799, -0.5297, -0.5192, 1.0754, 0.4732, -1.1667, 0.0922])

# %%
from pytspl.filters import ChebyshevFilterDesign

filter = ChebyshevFilterDesign(simplicial_complex=sc)

comp_coeffs = filter.get_component_coefficients(component="gradient")
filter.get_ideal_frequency(component_coeffs=comp_coeffs)
# Out:
# array([[ 0.62025316,  0.24050633,  0.13924051, -0.37974684, -0.10126582,
#         -0.03797468,  0.03797468,  0.02531646,  0.01265823, -0.01265823],
#        [ 0.24050633,  0.48101266,  0.27848101,  0.24050633, -0.20253165,
#         -0.07594937,  0.07594937,  0.05063291,  0.02531646, -0.02531646],
#        [ 0.13924051,  0.27848101,  0.58227848,  0.13924051,  0.30379747,
#          0.11392405, -0.11392405, -0.07594937, -0.03797468,  0.03797468],
#        [-0.37974684,  0.24050633,  0.13924051,  0.62025316, -0.10126582,
#         -0.03797468,  0.03797468,  0.02531646,  0.01265823, -0.01265823],
#        [-0.10126582, -0.20253165,  0.30379747, -0.10126582,  0.50632911,
#          0.18987342, -0.18987342, -0.12658228, -0.06329114,  0.06329114],
#        [-0.03797468, -0.07594937,  0.11392405, -0.03797468,  0.18987342,
#          0.69620253,  0.30379747,  0.20253165,  0.10126582, -0.10126582],
#        [ 0.03797468,  0.07594937, -0.11392405,  0.03797468, -0.18987342,
#          0.30379747,  0.69620253, -0.20253165, -0.10126582,  0.10126582],
#        [ 0.02531646,  0.05063291, -0.07594937,  0.02531646, -0.12658228,
#          0.20253165, -0.20253165,  0.53164557,  0.26582278, -0.26582278],
#        [ 0.01265823,  0.02531646, -0.03797468,  0.01265823, -0.06329114,
#          0.10126582, -0.10126582,  0.26582278,  0.63291139,  0.36708861],
#        [-0.01265823, -0.02531646,  0.03797468, -0.01265823,  0.06329114,
#         -0.10126582,  0.10126582, -0.26582278,  0.36708861,  0.63291139]])

# %%
filter.plot_chebyshev_series_approx(p_choice="L1L", n=10, cut_off_frequency=0.1, steep=100)

# %%
# apply filter
filter.apply(f=f, p_choice="L1L", component="gradient", L=20, cut_off_frequency=0.1)
# Out:
# Calculating Chebyshev filter approximation for k = 0...
# Calculating Chebyshev filter approximation for k = 1...
# Calculating Chebyshev filter approximation for k = 2...
# Calculating Chebyshev filter approximation for k = 3...
# Calculating Chebyshev filter approximation for k = 4...
# Calculating Chebyshev filter approximation for k = 5...
# Calculating Chebyshev filter approximation for k = 6...
# Calculating Chebyshev filter approximation for k = 7...
# Calculating Chebyshev filter approximation for k = 8...
# Calculating Chebyshev filter approximation for k = 9...
# Calculating Chebyshev filter approximation for k = 10...
# Calculating Chebyshev filter approximation for k = 11...
# Calculating Chebyshev filter approximation for k = 12...
# Calculating Chebyshev filter approximation for k = 13...
# Calculating Chebyshev filter approximation for k = 14...
# Calculating Chebyshev filter approximation for k = 15...
# Calculating Chebyshev filter approximation for k = 16...
# Calculating Chebyshev filter approximation for k = 17...
# Calculating Chebyshev filter approximation for k = 18...
# Calculating Chebyshev filter approximation for k = 19...
# Filter size: 0 - Error: 0.6310510403564362 - Filter error: 0.7637347496116356 - Error response: 0.6945307491111776
# Filter size: 1 - Error: 0.5093398089522972 - Filter error: 0.611102237727471 - Error response: 0.6977902169002802
# Filter size: 2 - Error: 0.38675945742803486 - Filter error: 0.46563447463906077 - Error response: 0.6851764278747313
# Filter size: 3 - Error: 0.27558345846494936 - Filter error: 0.3298994863012429 - Error response: 0.7197098817614646
# Filter size: 4 - Error: 0.1846339010728602 - Filter error: 0.20618017474837882 - Error response: 0.792587943786933
# Filter size: 5 - Error: 0.10385109891979173 - Filter error: 0.133694354242042 - Error response: 0.8155189506077788
# Filter size: 6 - Error: 0.050912638440443456 - Filter error: 0.06451697176840182 - Error response: 0.8194877516266647
# Filter size: 7 - Error: 0.06614500893519609 - Filter error: 0.07559140024782567 - Error response: 0.8488307234160702
# Filter size: 8 - Error: 0.11575372659650213 - Filter error: 0.1361040854029219 - Error response: 0.8730176719545144
# Filter size: 9 - Error: 0.14874652133288915 - Filter error: 0.1792648901444375 - Error response: 0.8866027190477098
# Filter size: 10 - Error: 0.16834983536837458 - Filter error: 0.2053963451767225 - Error response: 0.9050557544638878
# Filter size: 11 - Error: 0.17602360985295543 - Filter error: 0.21527853413611076 - Error response: 0.9133742874441849
# Filter size: 12 - Error: 0.17197886804339593 - Filter error: 0.21012160619363232 - Error response: 0.9108798848547176
# Filter size: 13 - Error: 0.15719486353889853 - Filter error: 0.1915279849909204 - Error response: 0.9025708732027565
# Filter size: 14 - Error: 0.1323957612473547 - Filter error: 0.16144582288434953 - Error response: 0.8860164873733523
# Filter size: 15 - Error: 0.10299589724317444 - Filter error: 0.12211527744890431 - Error response: 0.877190840381195
# Filter size: 16 - Error: 0.0708343256187204 - Filter error: 0.07600913885339555 - Error response: 0.8689114879034113
# Filter size: 17 - Error: 0.04123883865766937 - Filter error: 0.06268526434603476 - Error response: 0.8382095272408916
# Filter size: 18 - Error: 0.023866083861566672 - Filter error: 0.042634718346177006 - Error response: 0.8217551257776587
# Filter size: 19 - Error: 0.023866083861566672 - Filter error: 0.042634718346177006 - Error response: 0.8217551257776587

# %%
import matplotlib.pyplot as plt

extracted_comp_error = filter.history["extracted_component_error"]
filter_error = filter.history["filter_error"]

# plot the error
plt.figure(figsize=(15, 5))
plt.plot(extracted_comp_error)
#plt.plot(filter_error)
plt.xlabel("Filter size", fontdict={"fontsize": 16})
plt.ylabel("Error", fontdict={"fontsize": 16})
# change the x-axis font size
plt.xticks(fontsize=15)
# change the y-axis font size
plt.yticks(fontsize=15)

# change x-axis labels to integers
plt.xticks(np.arange(0, 20, 1))
# Out:
# ([<matplotlib.axis.XTick at 0x2943c86d0>,
#   <matplotlib.axis.XTick at 0x293afb010>,
#   <matplotlib.axis.XTick at 0x2943c0a90>,
#   <matplotlib.axis.XTick at 0x29443ba90>,
#   <matplotlib.axis.XTick at 0x294445e90>,
#   <matplotlib.axis.XTick at 0x294447310>,
#   <matplotlib.axis.XTick at 0x294451550>,
#   <matplotlib.axis.XTick at 0x294453690>,
#   <matplotlib.axis.XTick at 0x294455790>,
#   <matplotlib.axis.XTick at 0x294457a10>,
#   <matplotlib.axis.XTick at 0x29440ac50>,
#   <matplotlib.axis.XTick at 0x293acf4d0>,
#   <matplotlib.axis.XTick at 0x293adc350>,
#   <matplotlib.axis.XTick at 0x294454290>,
#   <matplotlib.axis.XTick at 0x293ad6d90>,
#   <matplotlib.axis.XTick at 0x293ae4310>,
#   <matplotlib.axis.XTick at 0x293ae6850>,
#   <matplotlib.axis.XTick at 0x293ad9510>,
#   <matplotlib.axis.XTick at 0x293ae7410>,
#   <matplotlib.axis.XTick at 0x293af8750>],
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19')])

# %%
filter.history["frequency_responses"][-1]
# Out:
# array([-4.53975746e-05, -1.04267918e+00, -4.53978687e-05,  1.02997907e+00,
#         4.53991581e-05,  1.01436892e+00,  9.81581636e-01, -4.53974333e-05,
#        -9.87744035e-01,  9.99965219e-01])

# %%
filter.plot_frequency_response_approx(flow=f, component="gradient")
plt.xticks(fontsize=15)
# change the y-axis font size
plt.yticks(fontsize=15)
plt.title("")
# Out:
# Text(0.5, 1.0, '')

# %%
error = filter.history["extracted_component_error"][-1]
print(f"Error: {error}")
# Out:
# Error: 0.023866083861566672
