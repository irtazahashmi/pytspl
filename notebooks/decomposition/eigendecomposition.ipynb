# %% [markdown]
# ### Eigendecomposition

# %%
import os

# set the current working directory
curr_path = os.getcwd().split("/")[:-2]
curr_path = "/".join(curr_path)
os.chdir(curr_path)

# %%
import numpy as np
from pytspl import load_dataset, SCPlot

sc, coordinates, _ = load_dataset("paper")
# create a plot
scplot = SCPlot(sc, coordinates)
# Out:
# Num. of nodes: 7
# Num. of edges: 10
# Num. of triangles: 3
# Shape: (7, 10, 3)
# Max Dimension: 2
# [(0, 1), (0, 2), (0, 3), (1, 2), (2, 3), (2, 5), (3, 4), (4, 5), (4, 6), (5, 6)] 10

# %% [markdown]
# #### Eigendecomposition

# %%
u_h, eigenvals_h = sc.get_eigendecomposition(component="harmonic")
u_c, eigenvals_c = sc.get_eigendecomposition(component="curl")
u_g, eigenvals_g = sc.get_eigendecomposition(component="gradient")

# %%
print("Eigenvalues:", eigenvals_h)
u_h
# Out:
# Eigenvalues: [0.]
# array([[ 0.06889728],
#        [ 0.13779456],
#        [-0.20669185],
#        [ 0.06889728],
#        [-0.34448641],
#        [ 0.55117825],
#        [-0.55117825],
#        [-0.36745217],
#        [-0.18372608],
#        [ 0.18372608]])

# %%
print("Eigenvalues:", eigenvals_c)
u_c
# Out:
# Eigenvalues: [2. 3. 4.]
# array([[ 0.5       ,  0.        ,  0.35355339],
#        [ 0.        ,  0.        , -0.70710678],
#        [-0.5       ,  0.        ,  0.35355339],
#        [ 0.5       ,  0.        ,  0.35355339],
#        [ 0.5       ,  0.        , -0.35355339],
#        [ 0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.57735027,  0.        ],
#        [ 0.        , -0.57735027,  0.        ],
#        [ 0.        ,  0.57735027,  0.        ]])

# %%
print("Eigenvalues:", eigenvals_g)
u_g
# Out:
# Eigenvalues: [0.81434921 2.32800901 3.3139076  3.59808935 4.45752963 5.4881152 ]
# array([[ 0.13607139,  0.48619685,  0.09433983, -0.46687335,  0.36745652,
#         -0.05878212],
#        [-0.18544569,  0.06525469,  0.31280028, -0.10648241,  0.47395312,
#          0.32946974],
#        [-0.29740454, -0.3267199 ,  0.02961399, -0.27923198,  0.53557877,
#         -0.1462567 ],
#        [-0.32151708, -0.42094216,  0.21846044,  0.36039095,  0.10649659,
#          0.38825186],
#        [-0.11195885, -0.39197459, -0.28318629, -0.17274957,  0.06162565,
#         -0.47572643],
#        [-0.59076521,  0.10910526,  0.21460989, -0.04279641, -0.21684759,
#         -0.49028892],
#        [-0.51395109,  0.26664402,  0.08504378, -0.29986768, -0.4131654 ,
#          0.30512138],
#        [ 0.03514474,  0.23443583,  0.4127524 ,  0.42982084,  0.13469216,
#         -0.31968387],
#        [-0.23514785,  0.39679702, -0.27091977,  0.50137606,  0.28346964,
#         -0.12263153],
#        [-0.27029259,  0.16236119, -0.68367217,  0.07155522,  0.14877749,
#          0.19705234]])

# %%
# plot without labels
scplot.draw_eigenvectors(component="gradient", with_labels=False)

# %%
# plot all the gradient eigenvectors
scplot.draw_eigenvectors(component="gradient")

# %%
# plot only the selected gradient eigenvectors
eig_vec_indices = np.array([0, 2, 5])
scplot.draw_eigenvectors(component="gradient", eigenvector_indices=eig_vec_indices)

# %%
# plot only the selected curl eigenvectors
eig_vec_indices = np.array([0, 2])
scplot.draw_eigenvectors(component="curl", eigenvector_indices=eig_vec_indices)

# %%
# plot harmonic eigenvectors
scplot.draw_eigenvectors(component="harmonic", figsize=(5, 5))
