# %%
import os

# set the current working directory
curr_path = os.getcwd().split("/")[:-1]
curr_path = "/".join(curr_path)
os.chdir(curr_path)

# %%
from sclibrary import dataset_loader, SCPlot

sc, coordinates = dataset_loader.load_paper_data()

scplot = SCPlot(simplical_complex=sc, coordinates=coordinates)

# %%
sc.edges
# Out:
# [(0, 1),
#  (0, 2),
#  (0, 3),
#  (1, 2),
#  (2, 3),
#  (2, 5),
#  (3, 4),
#  (4, 5),
#  (4, 6),
#  (5, 6)]

# %%
from matplotlib import pyplot as plt

fig, _ = plt.subplots(figsize=(10, 10))

edge_flow = [0, 1, 1, 1, 2, 4, 9, 2, 3, 1]
edges = [(0, 1),
 (0, 2),
 (0, 3),
 (1, 2),
 (2, 3),
 (2, 5),
 (3, 4),
 (4, 5),
 (4, 6),
 (5, 6)]


edge_flow = {
    edge: flow
    for edge, flow in zip(edges, edge_flow)
}

scplot.draw_sc_nodes(
    node_size=1000,
    font_size=25,
    with_labels=True
)
scplot.draw_sc_edges(
    edge_flow=edge_flow,
    edge_width=5,
    arrowsize=30
    
)

scplot.draw_edge_labels(
    edge_labels=edge_flow,
    font_size=20
)
# Out:
# /var/folders/py/wfd5gjj55nx4cqtdvltb22mw0000gp/T/ipykernel_55266/3945563367.py:23: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   scplot.draw_sc_nodes(
# /Users/irtaza.hashmi@futurice.com/Desktop/Thesis/sc-graph-library/sclibrary/plot/plot.py:180: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(
# /var/folders/py/wfd5gjj55nx4cqtdvltb22mw0000gp/T/ipykernel_55266/3945563367.py:28: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   scplot.draw_sc_edges(
# {(0, 1): Text(0.5, -0.25, '0'),
#  (0, 2): Text(0.0, -0.5, '1'),
#  (0, 3): Text(-0.5, -0.25, '1'),
#  (1, 2): Text(0.5, -0.75, '1'),
#  (2, 3): Text(-0.5, -0.75, '2'),
#  (2, 5): Text(0.0, -1.5, '4'),
#  (3, 4): Text(-1.0, -1.5, '9'),
#  (4, 5): Text(-0.5, -2.25, '2'),
#  (4, 6): Text(0.0, -2.5, '3'),
# ...
